# %% [markdown]
# <a href="https://colab.research.google.com/github/emilleishida/Fink_earlyTDE_v2/blob/main/notebooks/Preprocessing_cuts_and_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1. Load data**

# %%
#Run to download necessary files to the notebook

import pathlib
import os

data_dir = '/content'
pathlib.Path(data_dir).mkdir(parents=True, exist_ok=True)

files_to_download = {
    os.path.join(data_dir, "mallorn_data_fink_SNR_Full_LCs.pkl"): "1DNk-sk3a2fC1v8dCx6KqyHDjtxMLWi2W",
    os.path.join(data_dir, "mallorn_data_fink_SNR_30d_LCs.pkl"): "1bb1fgySX2KRMFxWLzSpFbLfq3vUOtWtj"}

for fpath, fid in files_to_download.items():
    url = f"https://drive.google.com/uc?id={fid}"
    if not os.path.exists(fpath):
        print(f"Downloading {os.path.basename(fpath)}...")
        # !gdown "{url}" -O "{fpath}"
    else:
        print(f"{os.path.basename(fpath)} already exists, skipping.")
# Out:
# Downloading mallorn_data_fink_SNR_Full_LCs.pkl...
# Downloading...
# From: https://drive.google.com/uc?id=1DNk-sk3a2fC1v8dCx6KqyHDjtxMLWi2W
# To: /content/mallorn_data_fink_SNR_Full_LCs.pkl
# 100% 31.7M/31.7M [00:00<00:00, 99.1MB/s]
# Downloading mallorn_data_fink_SNR_30d_LCs.pkl...
# Downloading...
# From: https://drive.google.com/uc?id=1bb1fgySX2KRMFxWLzSpFbLfq3vUOtWtj
# To: /content/mallorn_data_fink_SNR_30d_LCs.pkl
# 100% 33.7M/33.7M [00:00<00:00, 70.4MB/s]

# %%
# Load data
import pandas as pd
df = pd.read_pickle('mallorn_data_fink_SNR_30d_LCs.pkl')

# %%
df.head()
# Out:
#                   object_id  redshift    ebv SpecType  target  \
# 0  Dornhoth_fervain_onodrim    3.0490  0.110      AGN       0
# 1       Dornhoth_galadh_ylf    0.4324  0.058    SN II       0
# 2      Elrim_melethril_thul    0.4673  0.577      AGN       0
# 3        Ithil_tobas_rodwen    0.6946  0.012      AGN       0
# 4       Mirion_adar_Druadan    0.4161  0.058      AGN       0
#
#                                           lightcurve  n_detections  \
# 0             mjd    time_t0 filter      flux  fl...            13
# 1              mjd    time_t0 filter      flux  f...            11
# 2             mjd    time_t0 filter      flux  fl...            20
# 3              mjd    time_t0 filter      flux  f...            82
# 4              mjd    time_t0 filter      flux  f...            18
#
#                          lightcurve_preprocessed_30d
# 0             mjd   time_t0 filter      flux  flu...
# 1              mjd    time_t0 filter      flux  f...
# 2            mjd   time_t0 filter      flux  flux...
# 3              mjd   time_t0 filter      flux  fl...
# 4             mjd   time_t0 filter      flux  flu...

# %% [markdown]
# ### **2. Define filtering Functions**

# %%
import numpy as np

def get_slope(x, y, dy):
    x = np.atleast_1d(x)
    y = np.atleast_1d(y)
    dy = np.atleast_1d(dy)

    idx = np.isfinite(x) & np.isfinite(y) & np.isfinite(dy)

    if len(x[idx]) < 3 or np.ptp(x[idx]) == 0:
        return 0, 0

    p, cov = np.polyfit(
        x[idx] - np.mean(x[idx]), y[idx] - np.mean(y), 1, w=1 / dy[idx], cov="unscaled"
    )
    dp = np.sqrt(np.diag(cov))

    return p[0], dp[0]


def is_rising(
    jd,
    flux,
    fluxerr,
    filter,
    upper=None,
    nsigmas_rise=2,
    nsigmas_decay=1,
    nsigmas_slope=3,
    use_slope=True,
    verbose=False,
):
    idx0 = flux == flux

    is_decay = False
    is_rise = False

    for filt in ['u', 'g', 'r', 'i', 'z', 'y']:

        idx = idx0 & (filter == filt)
        uidx = ~idx0 & (filter == filt)

        if np.sum(idx) < 2:
            continue

        # Last point is significantly lower than the max?..
        diff = flux[idx][:-1] - flux[idx][-1]
        differr = np.hypot(fluxerr[idx][:-1], fluxerr[idx][-1])

        if np.any(diff > nsigmas_decay * differr):
            is_decay = True

        # Last point is significantly higher than the min?..
        diff = flux[idx][-1] - flux[idx][:-1]

        if np.any(diff > nsigmas_rise * differr):
            is_rise = True

        if np.sum(idx) >= 3 and use_slope:
            # Slope is significantly positive?..
            slope, serr = get_slope(jd[idx], flux[idx], fluxerr[idx])
            if verbose:
                print("slope", slope, "+/-", serr)
            if slope > nsigmas_slope * serr:
                is_rise = True

        # Any point is significantly lower than the previous?..
        diff = flux[idx][:-1] - flux[idx][1:]
        differr = np.hypot(fluxerr[idx][:-1], fluxerr[idx][1:])

        if np.any(diff > nsigmas_decay * differr):
            is_decay = True

        # Last point is significantly higher than any (prior) upper limit?..
        if upper is not None and np.sum(uidx) > 0:
            diff = flux[idx][-1] - upper[uidx]
            differr = fluxerr[idx][-1]

            if np.any(diff > nsigmas_rise * differr):
                is_rise = True

    if verbose:
        print("rise", is_rise, "decay", is_decay)

    return is_rise and not is_decay

# %% [markdown]
# ### **3. Apply rising flags**

# %%
df = df[~df['lightcurve_preprocessed_30d'].isna()]

mask = []
for _, row in df.iterrows():

  mjd = row["lightcurve_preprocessed_30d"]["mjd"].to_numpy()
  flux = row["lightcurve_preprocessed_30d"]["flux_dered"].to_numpy()
  flux_err = row["lightcurve_preprocessed_30d"]["flux_err_dered"].to_numpy()
  filter = row["lightcurve_preprocessed_30d"]["filter"]

  mask.append(is_rising(mjd, flux, flux_err, filter, verbose = False))

df_rising = df[mask]

print(len(df_rising))
# Out:
# 694

# %% [markdown]
# ### **4. Apply other cuts (e.g. 5 points minimum)**

# %%
df_5points = df_rising[
	df_rising["lightcurve_preprocessed_30d"].apply(lambda lc: len(lc) >= 5)]
print(len(df_5points))
# Out:
# 576

# %% [markdown]
# ### **5. Apply feature extraction**

# %%
try:
  from light_curve.light_curve_py import RainbowFit
except ModuleNotFoundError:

  # !git clone https://github.com/light-curve/light-curve-python.git
  # !pip install 'light-curve[full]'
  from light_curve.light_curve_py import RainbowFit
# Out:
# Cloning into 'light-curve-python'...
# remote: Enumerating objects: 19703, done.
# remote: Counting objects: 100% (726/726), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 19703 (delta 671), reused 594 (delta 586), pack-reused 18977 (from 3)
# Receiving objects: 100% (19703/19703), 50.59 MiB | 15.49 MiB/s, done.
# Resolving deltas: 100% (8933/8933), done.
# Collecting light-curve[full]
#   Downloading light_curve-0.11.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from light-curve[full]) (2.0.2)
# Collecting iminuit<3,>=2.21 (from light-curve[full])
#   Downloading iminuit-2.32.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.12/dist-packages (from light-curve[full]) (1.16.3)
# Downloading iminuit-2.32.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (448 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.2/448.2 kB 12.0 MB/s eta 0:00:00
# Downloading light_curve-0.11.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (45.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 MB 17.0 MB/s eta 0:00:00
# Installing collected packages: light-curve, iminuit
# Successfully installed iminuit-2.32.0 light-curve-0.11.1

# %%
df_5points["lightcurve_preprocessed_30d"].iloc[0].columns
# Out:
# Index(['mjd', 'time_t0', 'filter', 'flux', 'flux_err', 'SNR', 'flux_dered',
#        'flux_err_dered', 'detection_5SNR', 'detection_3SNR'],
#       dtype='object')

# %%
band_wave_aa = {  # Wavelenght in angstrom for Rainbow in LSST
      "u": 3671.0,
      "g": 4827.0,
      "r": 6223.0,
      "i": 7546.0,
      "z": 8691.0,
      "Y": 9712.0,
  }
feature = RainbowFit.from_angstrom(
    band_wave_aa,
    with_baseline=False,
    temperature="constant",
    bolometric="sigmoid",
)


def apply_rainbow_fit(sub, nsamples=None):

    mjd = sub["mjd"].to_numpy()
    flux, fluxerr = sub["flux_dered"].to_numpy(), sub["flux_err_dered"].to_numpy()
    band = sub["filter"]

    try:
        params, errors, cov = feature._eval_and_get_errors(
            t=mjd,
            m=flux,
            sigma=fluxerr,
            band=band,
            # upper_mask=~idx_good,
            return_covariance=True,
            debug=True,
        )

        result = {}
        result["params"] = params
        result["errors"] = errors
        result["cov"] = cov

        if nsamples is not None:
            samples = []

            while True:
                params1 = np.random.multivariate_normal(params[:-1], cov)
                # Sanity checks
                if params1[feature.p["amplitude"]] < 0:
                    continue

                samples.append(params1)
                if len(samples) >= nsamples:
                    result["samples"] = samples
                    break

        return result
    except KeyboardInterrupt:
        raise
    except Exception:  # FIXME
        return None

def extract_features(sub, nsamples=None, post_fit_filtering = True):
        # Extract Rainbow features - best fit and sampled according to covariances
        res1 = apply_rainbow_fit(sub, nsamples=nsamples)
        jd_max=np.max(sub["mjd"])
        # Initial quality cuts for the fit
        if res1 is None:
            return

        # Actual features
        res = {}
        for i, name in enumerate(feature.names):
            if name == "T":
                # Normalize temperature name
                name = "temperature"
            if nsamples is None:
              res[name] = res1["params"][i]
            else:
              res[name] = np.array([res1["params"][i]] + [_[i] for _ in res1["samples"]])

            res["e_" + name] = res1["errors"][i]

            if name not in ["reference_time"]:
                res["snr_" + name] = np.abs(res1["params"][i] / res1["errors"][i])

        res["r_chisq"] = res1["params"][-1]
        res["rel_reference_time"] = res["reference_time"] - jd_max
        res["norm_rel_reference_time"] = res["rel_reference_time"] / res["rise_time"]
        # res["distnr"] = np.nanmin(pdf["i:distnr"])


        # Features quality cuts
        norm_rel_best = res["norm_rel_reference_time"] if nsamples is None else res["norm_rel_reference_time"][0]
        if post_fit_filtering and (
            res["r_chisq"] > 10
            or res["e_reference_time"] > 100
            or norm_rel_best > 1
            or norm_rel_best < -10
            or
            # res['snr_amplitude'] < 1.5 or
            res["snr_rise_time"] < 1.5
            or res["snr_temperature"] < 1.5
        ):
            return
        return res

def extract_features_no_cuts(sub):
  return extract_features(sub, post_fit_filtering=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/light_curve/light_curve_py/warnings.py:19: ExperimentalWarning: Function light_curve.light_curve_py.features.rainbow.generic.RainbowFit is experimental and may cause any kind of troubles
#   warn_experimental(message)

# %%
# Extract features and do not apply post-fit cuts
features_df_no_cuts = (
	df_5points["lightcurve_preprocessed_30d"]
	.apply(extract_features_no_cuts)
	.apply(pd.Series)
)
df_with_feat_no_cuts = pd.concat([df_5points, features_df_no_cuts], axis=1)

# Extract features and apply cuts
features_df = (
	df_5points["lightcurve_preprocessed_30d"]
	.apply(extract_features)
	.apply(pd.Series)
)

df_with_feat = pd.concat([df_5points, features_df], axis=1)

# Remove rows that are NaN
df_with_feat_no_cuts = df_with_feat_no_cuts[
	~df_with_feat_no_cuts.reference_time.isna()
]
df_with_feat = df_with_feat[
	~df_with_feat.reference_time.isna()
]
# Out:
# /usr/local/lib/python3.12/dist-packages/light_curve/light_curve_py/features/rainbow/bolometric.py:338: RuntimeWarning: invalid value encountered in scalar divide
#   t0 = np.sum(t[idx] * m[idx] / sigma[idx]) / np.sum(m[idx] / sigma[idx])
# /usr/local/lib/python3.12/dist-packages/light_curve/light_curve_py/features/rainbow/bolometric.py:341: RuntimeWarning: invalid value encountered in scalar divide
#   dt = np.sqrt(np.sum((t[idx] - t0) ** 2 * (mc[idx]) / sigma[idx]) / np.sum(mc[idx] / sigma[idx]))
# /usr/local/lib/python3.12/dist-packages/light_curve/light_curve_py/features/rainbow/bolometric.py:338: RuntimeWarning: invalid value encountered in scalar divide
#   t0 = np.sum(t[idx] * m[idx] / sigma[idx]) / np.sum(m[idx] / sigma[idx])
# /usr/local/lib/python3.12/dist-packages/light_curve/light_curve_py/features/rainbow/bolometric.py:341: RuntimeWarning: invalid value encountered in scalar divide
#   dt = np.sqrt(np.sum((t[idx] - t0) ** 2 * (mc[idx]) / sigma[idx]) / np.sum(mc[idx] / sigma[idx]))

# %%
df_with_feat = df_with_feat[
	~df_with_feat.reference_time.isna()
]

# %% [markdown]
# # Analysis and plots

# %%
def count_types(df):
	return [
		len(df),
		(df.SpecType == "AGN").sum(),
		(df.SpecType == "TDE").sum(),
		(~df["SpecType"].isin(["AGN", "TDE"])).sum(),
	]

summary = pd.DataFrame(
	[
		["Original dataset"]      + count_types(df),
		["After rising cut"]      + count_types(df_rising),
		["Minimum 5 points"]      + count_types(df_5points),
		["After Rainbow fit"]     + count_types(df_with_feat_no_cuts),
		["After post-fit cuts"]   + count_types(df_with_feat),
	],
	columns=["Stage", "Total", "AGN", "TDEs", "Others"]
)

print(summary.to_string(index=False))
# Out:
#               Stage  Total  AGN  TDEs  Others
#    Original dataset   3021 1764   148    1109
#    After rising cut    694  116    46     532
#    Minimum 5 points    576   90    33     453
#   After Rainbow fit    153   38    10     105
# After post-fit cuts     31    3     5      23

# %%
# Plotting
import matplotlib.pyplot as plt
ax = plt.figure(figsize=(10,8)).gca()
COLORS_ZTF = {1: "#15284F", 2: "#F5622E", 3: "#3C8DFF", 4: "#D5D5D3"}

agn_index = df_with_feat.SpecType == "AGN"
tde_idx = df_with_feat.SpecType == "TDE"


# plt.plot(features['rise_time'][good_idx & ~tde_idx & ~sn_idx], features['T'][good_idx & ~tde_idx & ~sn_idx], '.', alpha=0.2, label='All objects')
plt.plot(df_with_feat['rise_time'][tde_idx], df_with_feat['temperature'][tde_idx], 'o', color=COLORS_ZTF[2], ms=10, label='TDEs')
plt.plot(df_with_feat['rise_time'][agn_index], df_with_feat['temperature'][agn_index], '*', color=COLORS_ZTF[1], ms = 10, label='AGN', rasterized=True)
plt.plot(df_with_feat['rise_time'][~tde_idx & ~agn_index], df_with_feat['temperature'][~tde_idx & ~agn_index], '.', ms=10, color=COLORS_ZTF[3], label='Other', rasterized=True)

# plt.plot(features['rise_time'][good_idx & fleet_idx], features['T'][good_idx & fleet_idx], 'o', color='magenta', label='FLEETs')

# plt.legend(fontsize=18)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Rise time (days)', fontsize = 20)
plt.ylabel('Temperature (K)', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=16) #, width=2.5, length=10)
# plt.grid(alpha=0.2)
plt.xlim(3e-1, 3e2)
plt.ylim(2e3, 5e4)

ax.legend(fontsize = 18)
